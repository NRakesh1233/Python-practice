# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
movies=pd.read_csv(r"C:\Users\RAKESH\Downloads\archive (1)\movie.csv")

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='str')

# %%
movies.head(5)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.describe()
# Out:
#              movieId
# count   27278.000000
# mean    59855.480570
# std     44429.314697
# min         1.000000
# 25%      6931.250000
# 50%     68068.000000
# 75%    100293.250000
# max    131262.000000

# %%
tags=pd.read_csv(r"C:\\Users\\RAKESH\\Downloads\\archive (1)\\tag.csv")

# %%
tags.shape
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
ratings=pd.read_csv(r"C:\\Users\\RAKESH\\Downloads\\archive (1)\\rating.csv")
ratings.head(10)
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40
# 5       1      112     3.5  2004-09-10 03:09:00
# 6       1      151     4.0  2004-09-10 03:08:54
# 7       1      223     4.0  2005-04-02 23:46:13
# 8       1      253     4.0  2005-04-02 23:35:40
# 9       1      260     4.0  2005-04-02 23:33:46

# %%
ratings.shape
# Out:
# (20000263, 4)

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='str')

# %%
ratings.drop('timestamp', axis=1,inplace=True)

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
del tags['timestamp']

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
row0=ratings.iloc[0]
type(row0)
# Out:
# pandas.Series

# %%
row0
row0.index
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='str')

# %%
row0['userId']
# Out:
# np.float64(1.0)

# %%
row0[:]
# Out:
# userId     1.0
# movieId    2.0
# rating     3.5
# Name: 0, dtype: float64

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='str')

# %%
'rating' in ratings
# Out:
# True

# %%
row0.name
# Out:
# 0

# %%
row0.rename('firstrow')
# Out:
# userId     1.0
# movieId    2.0
# rating     3.5
# Name: firstrow, dtype: float64

# %%
tags.index
ratings.index
# Out:
# RangeIndex(start=0, stop=20000263, step=1)

# %%
ratings.iloc[[0,100]]
# Out:
#      userId  movieId  rating
# 0         1        2     3.5
# 100       1     3037     3.5

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
filter1=ratings['rating']>3
filter1
sum(filter1)
# Out:
# 12195566

# %%
filter1.all()
# Out:
# np.False_

# %%
movies.isnull().any().any()
# Out:
# np.False_

# %%
tags.isnull().any().any()
# Out:
# np.True_

# %%
tags.shape
# Out:
# (465564, 3)

# %%
tags=tags.dropna()

# %%
tags.isnull().any().any()
# Out:
# np.False_

# %%
tags.shape
# Out:
# (465548, 3)

# %% [markdown]
# Data visulization

# %%
# %matplotlib inline

# %%
ratings.hist('rating',figsize=(5,2))
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
ratings.boxplot('rating')
# Out:
# <Axes: >

# %%
ratings[-10:]
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %%
tag_count=tags['tag'].value_counts()

# %%
tag_count[:]
# Out:
# tag
# sci-fi                                                                  3384
# based on a book                                                         3281
# atmospheric                                                             2917
# comedy                                                                  2779
# action                                                                  2657
#                                                                         ...
# Disguises                                                                  1
# retarted                                                                   1
# circle k                                                                   1
# This movie should have been called \\"How Cocaine Ruined Disney\"\""       1
# topless scene                                                              1
# Name: count, Length: 38643, dtype: int64

# %%
tag_count[:10].plot(kind='bar',figsize=(10,5))
# Out:
# <Axes: xlabel='tag'>

# %%
high_rated=ratings['rating']>=5

ratings[high_rated][30:50]
# Out:
#      userId  movieId  rating
# 239       3       50     5.0
# 242       3      175     5.0
# 244       3      223     5.0
# 245       3      260     5.0
# 246       3      316     5.0
# 247       3      318     5.0
# 248       3      329     5.0
# 252       3      457     5.0
# 253       3      480     5.0
# 254       3      490     5.0
# 256       3      541     5.0
# 258       3      593     5.0
# 263       3      858     5.0
# 264       3      904     5.0
# 267       3      924     5.0
# 268       3      953     5.0
# 271       3     1060     5.0
# 272       3     1073     5.0
# 275       3     1084     5.0
# 276       3     1089     5.0

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='str')

# %%
movies['movieId'].plot()
# Out:
# <Axes: >
# Running cells with 'Python 3.13.15' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/RAKESH/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
movies[0:200]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 movies[0:200]
#
# NameError: name 'movies' is not defined
