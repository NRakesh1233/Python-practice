# %%
t=(1,2,3,4,5)
t
# Out:
# (1, 2, 3, 4, 5)

# %%
type(t)
t1=("rakesh",[1,23,5,6],(1,2,3))
t1
# Out:
# ('rakesh', [1, 23, 5, 6], (1, 2, 3))

# %%
print(type(t1[1]))
print(t1[1][2])
# Out:
# <class 'list'>
# 5

# %%
#t1[2][0]=4
t1[:2]
# Out:
# ('rakesh', [1, 23, 5, 6])

# %%
del t1

# %%
for i in t1 :
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 for i in t1 :
#       2     print(i)
#
# NameError: name 't1' is not defined

# %%
t1.count(t1[1])
# Out:
# 0

# %%
t2=(1,2,3,4,5,6,1,2,3,4,5,6)

9 in t2
# Out:
# False

# %%
sorted(t2 , reverse=True)
# Out:
# [6, 6, 5, 5, 4, 4, 3, 3, 2, 2, 1, 1]

# %%
tuple("rakesh")
# Out:
# ('r', 'a', 'k', 'e', 's', 'h')

# %% [markdown]
# sets practice

# %%
s1=set(t2)
s1
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s1.discard(6)
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s2={1,2,3,[1,2,3,4,5,6,7,8]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 s2={1,2,3,[1,2,3,4,5,6,7,8]}
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %%
s2=set([4,5,6,7,8])
s1 | s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1 & s2
s1.intersection_update(s2)
s1
# Out:
# {4, 5, 6, 7, 8}

# %%
s1.update(s2)
s1
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 3, 7, 8}
